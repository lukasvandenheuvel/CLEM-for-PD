# %% [markdown]
# # Initialize
# - Open a terminal (in visual studio code: Terminal > new terminal) and check whether you have conda:
#     ```bash
#     conda --version
#     ```
#
# - If you don't have conda (message 'no command conda ...'), install it here: https://docs.conda.io/projects/miniconda/en/latest/
#     > Make sure you check the 'add conda to PATH variable tickbox!'
#
#     Then re-start Visual Studio Code and check again with ```conda --version```.
#
# - In your terminal, move to the path where the ```ReadLif``` folder is placed with the command
#     ```bash
#     cd /path/to/ReadLif
#     ```
#
# - Create a virtual python environment by running the following command in your terminal:
#     ```bash
#     conda env create -f requirements.yml
#     ```
#     This may take some time to execute.
# - Once this is done, restart Visual Studio Code and open this notebook again.
#     On the top right, click "Select Kernel". You should see the name ```ada``` appear in the list of kernels. Select it.
#     If you don't see ```ada```, click "Select another kernel", then "Python Environments...". It should be there, otherwise contact me.
#
# - You are now ready to run the code!

# %% [markdown]
# # Import functions and packages

# %%
from LifReader import LifReader
import os

# %% [markdown]
# # Set input and output paths

# %%
lif_path    = '/Volumes/LBEM/THUNDER/lukas/MasterThesis/Data_raw/Thunder/LH01_A02_2020-015/2020-015 SN 81A-NFH-Ubiquitin A02.lif' # Path to a .lif file
output_path = '/Users/lukasvandenheuvel/Documents/EPFL/MA4/PDM/Data_processed/test' # Path to a folder where you want the .tiff files to be stored
reader      = LifReader(lif_path)
# Out:
# Loaded 16 images in /Volumes/LBEM/THUNDER/lukas/MasterThesis/Data_raw/Thunder/LH01_A02_2020-015/2020-015 SN 81A-NFH-Ubiquitin A02.lif
# Image names:
# Img 0: TileScan 1, dims = (2048 x 2048 x 1 x 1 x 1)  scale = (1.5384615384615385, 1.5384615384615385, None, None) px/um
# Img 1: TileScan 1_ICC, dims = (2048 x 2048 x 1 x 1 x 35)  scale = (1.5384615384615385, 1.5384615384615385, None, None) px/um
# Img 2: TileScan 1_ICC Merged, dims = (11260 x 13102 x 1 x 1 x 1)  scale = (1.5384615384615385, 1.5384615384615383, None, None) px/um
# Img 3: TileScan 2, dims = (2048 x 2048 x 1 x 1 x 35)  scale = (1.5384615384615385, 1.5384615384615385, None, None) px/um
# Img 4: TileScan 2_ICC, dims = (2048 x 2048 x 1 x 1 x 35)  scale = (1.5384615384615385, 1.5384615384615385, None, None) px/um
# Img 5: TileScan 2_ICC Merged, dims = (11141 x 12954 x 1 x 1 x 1)  scale = (1.5384615384615383, 1.5384615384615385, None, None) px/um
# Img 6: Series001, dims = (2048 x 2048 x 68 x 1 x 1)  scale = (9.69230827506269, 9.69230827506269, -3.3311125916055966, None) px/um
# Img 7: Series001_Lng_LVCC, dims = (2048 x 2048 x 68 x 1 x 1)  scale = (9.69230827506269, 9.69230827506269, -3.3311125916055966, None) px/um
# Img 8: Series002, dims = (2048 x 2048 x 24 x 1 x 1)  scale = (9.69230827506269, 9.69230827506269, 3.331112591605596, None) px/um
# Img 9: Series002_Lng_LVCC, dims = (2048 x 2048 x 24 x 1 x 1)  scale = (9.69230827506269, 9.69230827506269, 3.331112591605596, None) px/um
# Img 10: Series003, dims = (2048 x 2048 x 28 x 1 x 1)  scale = (9.69230827506269, 9.69230827506269, 3.3311125916055966, None) px/um
# Img 11: Series003_Lng_LVCC, dims = (2048 x 2048 x 28 x 1 x 1)  scale = (9.69230827506269, 9.69230827506269, 3.3311125916055966, None) px/um
# Img 12: Series004, dims = (2048 x 2048 x 60 x 1 x 1)  scale = (9.69230827506269, 9.69230827506269, 3.331112591605596, None) px/um
# Img 13: Series004_Lng_LVCC, dims = (2048 x 2048 x 60 x 1 x 1)  scale = (9.69230827506269, 9.69230827506269, 3.331112591605596, None) px/um
# Img 14: Series005, dims = (2048 x 2048 x 38 x 1 x 1)  scale = (9.69230827506269, 9.69230827506269, -3.331112591605596, None) px/um
# Img 15: Series005_Lng_LVCC, dims = (2048 x 2048 x 38 x 1 x 1)  scale = (9.69230827506269, 9.69230827506269, -3.331112591605596, None) px/um

# %% [markdown]
# # Select images
# Above, you see a list of all scans in your LIF project.
# With the cell below, you can filter scans you want to save as TIFF.
# Example: if you only want scans with LVCC in their name to be saved as TIFF, enter
# ```python
# filter = 'LVCC'
# ```
# If you want all scans to be saved as TIFF, enter
# ```python
# filter = 'all'
# ```
#
# In ```channels_to_save```, select channels you would like to save.
# Example: if you only want to save the first channel, enter
# ```python
# channels_to_save = [0]
# ```
# If you want to save channels 0 and 2, enter
# ```python
# channels_to_save = [0,2]
# ```
# If you want to save all channels, enter
# ```python
# channels_to_save = 'all'
# ```

# %%
filter = 'all'
channels_to_save = 'all'

# %% [markdown]
# # Save the images
# Run the cell below to start the export.

# %%
# Obtain scans to save
if filter=='all':
    scan_nrs = list(range(reader.lif.num_images))
else:
    scan_nrs = [f for f in range(reader.lif.num_images) if filter in reader.lif.get_image(f).name]
print(f'Selected {len(scan_nrs)} scans to save.')

# Loop over scans and save tiles
for nr in scan_nrs:
    if channels_to_save=='all':
        channels = list(range(reader.lif.get_image(nr).channels))
    else:
        channels = channels_to_save
    reader.save_zstack(nr,output_path,channels=channels)
print('Done!')
# Out:
# Selected 16 scans to save.
# Made new tile folder
# Starting tile 0 out of 1...
# Starting channel 0 out of 2...
# Saved img m000_ch00_z000.tif
# Starting channel 1 out of 2...
# Saved img m000_ch01_z000.tif
# Made new tile folder
# Starting tile 0 out of 35...
# Starting channel 0 out of 2...
# Saved img m000_ch00_z000.tif
# Starting channel 1 out of 2...
# Saved img m000_ch01_z000.tif
# Starting tile 1 out of 35...
# Starting channel 0 out of 2...
# Saved img m001_ch00_z000.tif
# Starting channel 1 out of 2...
# Saved img m001_ch01_z000.tif
# Starting tile 2 out of 35...
# Starting channel 0 out of 2...
# Saved img m002_ch00_z000.tif
# Starting channel 1 out of 2...
# Saved img m002_ch01_z000.tif
# Starting tile 3 out of 35...
# Starting channel 0 out of 2...
# Saved img m003_ch00_z000.tif
# Starting channel 1 out of 2...
# Saved img m003_ch01_z000.tif
# Starting tile 4 out of 35...
# Starting channel 0 out of 2...
# Saved img m004_ch00_z000.tif
# Starting channel 1 out of 2...
# Saved img m004_ch01_z000.tif
# Starting tile 5 out of 35...
# Starting channel 0 out of 2...
# Saved img m005_ch00_z000.tif
# Starting channel 1 out of 2...
# Saved img m005_ch01_z000.tif
# Starting tile 6 out of 35...
# Starting channel 0 out of 2...
# Saved img m006_ch00_z000.tif
# Starting channel 1 out of 2...
# Saved img m006_ch01_z000.tif
# Starting tile 7 out of 35...
# Starting channel 0 out of 2...
# Saved img m007_ch00_z000.tif
# Starting channel 1 out of 2...
# Saved img m007_ch01_z000.tif
# Starting tile 8 out of 35...
# Starting channel 0 out of 2...
# Saved img m008_ch00_z000.tif
# Starting channel 1 out of 2...
# Saved img m008_ch01_z000.tif
# Starting tile 9 out of 35...
# Starting channel 0 out of 2...
# Saved img m009_ch00_z000.tif
# Starting channel 1 out of 2...
# Saved img m009_ch01_z000.tif
# Starting tile 10 out of 35...
# Starting channel 0 out of 2...
# Saved img m010_ch00_z000.tif
# Starting channel 1 out of 2...
# Saved img m010_ch01_z000.tif
# Starting tile 11 out of 35...
# Starting channel 0 out of 2...
# Saved img m011_ch00_z000.tif
# Starting channel 1 out of 2...
# Saved img
ch00_z000.tif
# Starting channel 1 out of 2...
# Saved img m033_ch01_z000.tif
# Starting tile 34 out of 35...
# Starting channel 0 out of 2...
# Saved img m034_ch00_z000.tif
# Starting channel 1 out of 2...
# Saved img m034_ch01_z000.tif
# Made new tile folder
# Starting tile 0 out of 1...
# Starting channel 0 out of 2...
# Saved img m000_ch00_z000.tif
# Starting channel 1 out of 2...
# Saved img m000_ch01_z000.tif
# Made new tile folder
# Starting tile 0 out of 1...
# Starting channel 0 out of 5...
# Saved img m000_ch00_z000.tif
# Saved img m000_ch00_z001.tif
# Saved img m000_ch00_z002.tif
# Saved img m000_ch00_z003.tif
# Saved img m000_ch00_z004.tif
# Saved img m000_ch00_z005.tif
# Saved img m000_ch00_z006.tif
# Saved img m000_ch00_z007.tif
# Saved img m000_ch00_z008.tif
# Saved img m000_ch00_z009.tif
# Saved img m000_ch00_z010.tif
# Saved img m000_ch00_z011.tif
# Saved img m000_ch00_z012.tif
# Saved img m000_ch00_z013.tif
# Saved img m000_ch00_z014.tif
# Saved img m000_ch00_z015.tif
# Saved img m000_ch00_z016.tif
# Saved img m000_ch00_z017.tif
# Saved img m000_ch00_z018.tif
# Saved img m000_ch00_z019.tif
# Saved img m000_ch00_z020.tif
# Saved img m000_ch00_z021.tif
# Saved img m000_ch00_z022.tif
# Saved img m000_ch00_z023.tif
# Saved img m000_ch00_z024.tif
# Saved img m000_ch00_z025.tif
# Saved img m000_ch00_z026.tif
# Saved img m000_ch00_z027.tif
# Saved img m000_ch00_z028.tif
# Saved img m000_ch00_z029.tif
# Saved img m000_ch00_z030.tif
# Saved img m000_ch00_z031.tif
# Saved img m000_ch00_z032.tif
# Saved img m000_ch00_z033.tif
# Saved img m000_ch00_z034.tif
# Saved img m000_ch00_z035.tif
# Saved img m000_ch00_z036.tif
# Saved img m000_ch00_z037.tif
# Saved img m000_ch00_z038.tif
# Saved img m000_ch00_z039.tif
# Saved img m000_ch00_z040.tif
# Saved img m000_ch00_z041.tif
# Saved img m000_ch00_z042.tif
# Saved img m000_ch00_z043.tif
# Saved img m000_ch00_z044.tif
# Saved img m000_ch00_z045.tif
# Saved img m000_ch00_z046.tif
# Saved img m000_ch00_z047.tif
# Saved img m000_ch00_z048.tif
# Saved img m000_ch00_z049.tif
# Saved img m000_ch00_z050.tif
# Saved img m000_ch00_z051.tif
# Saved img m000_ch00_z052.tif
# Saved img m000_ch00_z053.tif
# Saved img m000_ch00_z054.tif
# Saved img m000_ch00_z055.tif
# Saved img m000_ch00_z056.tif
# Saved img m000_ch00_z057.tif
# Saved img m000_ch00_z058.tif
# Saved img m000_ch00_z059.tif
# Saved img m000_ch00_z060.tif
# Saved img m000_ch00_z061.tif
# Saved img m000_ch00_z062.tif
# Saved img m000_ch00_z063.tif
# Saved img m000_ch00_z064.tif
# Saved img m000_ch00_z065.tif
# Saved img m000_ch00_z066.tif
# Saved img m000_ch00_z067.tif
# Starting channel 1 out of 5...
# Saved img m000_ch01_z000.tif
# Saved img m000_ch01_z001.tif
# Saved img m000_ch01_z002.tif
# Saved img m000_ch01_z003.tif
# Saved img m000_ch01_z004.tif
# Saved img m000_ch01_z005.tif
# Saved img m000_ch01_z006.tif
# Saved img m000_ch01_z007.tif
# Saved img m000_ch01_z008.tif
# Saved img m000_ch01_z009.tif
# Saved img m000_ch01_z010.tif
# Saved img m000_ch01_z011.tif
# Saved img m000_ch01_z012.tif
# Saved img m000_ch01_z013.tif
# Saved img m000_ch01_z014.tif
# Saved img m000_ch01_z015.tif
# Saved img m000_ch01_z016.tif
# Saved img m000_ch01_z017.tif
# Saved img m000_ch01_z018.tif
# Saved img m000_ch01_z019.tif
# Saved img m000_ch01_z020.tif
# Saved img m000_ch01_z021.tif
# Saved img m000_ch01_z022.tif
# Saved img m000_ch01_z023.tif
# Saved img m000_ch01_z024.tif
# Saved img m000_ch01_z025.tif
# Saved img m000_ch01_z026.tif
# Saved img m000_ch01_z027.tif
# Saved img m000_ch01_z028.tif
# Saved img m000_ch01_z029.tif
# Saved img m000_ch01_z030.tif
# Saved img m000_ch01_z031.tif
# Saved img m000_ch01_z032.tif
# Saved img m000_ch01_z033.tif
# Saved img m000_ch01_z034.tif
# Saved img m000_ch01_z035.tif
# Saved img m000_ch01_z036.tif
# Saved img m000_ch01_z037.tif
# Saved img m000_ch01_z038.tif
# Saved img m000_ch01_z039.tif
# Saved img m000_ch01_z040.tif
# Saved img m000_ch01_z041.tif
# Saved img m000_ch01_z042.tif
# Saved img m000_ch01_z043.tif
# Saved img m000_ch01_z044.tif
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /Users/lukasvandenheuvel/Documents/EPFL/MA4/PDM/CLEM-for-PD/ReadLif/readlif.ipynb Cell 8 line 1
#      <a href='vscode-notebook-cell:/Users/lukasvandenheuvel/Documents/EPFL/MA4/PDM/CLEM-for-PD/ReadLif/readlif.ipynb#X25sZmlsZQ%3D%3D?line=10'>11</a> else:
#      <a href='vscode-notebook-cell:/Users/lukasvandenheuvel/Documents/EPFL/MA4/PDM/CLEM-for-PD/ReadLif/readlif.ipynb#X25sZmlsZQ%3D%3D?line=11'>12</a>     channels = channels_to_save
# ---> <a href='vscode-notebook-cell:/Users/lukasvandenheuvel/Documents/EPFL/MA4/PDM/CLEM-for-PD/ReadLif/readlif.ipynb#X25sZmlsZQ%3D%3D?line=12'>13</a> reader.save_zstack(nr,output_path,channels=channels)
#
# File ~/Documents/EPFL/MA4/PDM/CLEM-for-PD/ReadLif/LifReader.py:45, in LifReader.save_zstack(self, f, output_path, t, channels)
#      43 for z in range(img.dims.z):
#      44     img_name = f'm{m:03d}_ch{ch:02d}_z{z:03d}.tif'
# ---> 45     frame = np.array(img.get_frame(z=z,t=t,c=ch,m=m))
#      46     io.imsave(os.path.join(tiles_path,f'{img_name}'), frame, check_contrast=False)
#      47     print(f'Saved img {img_name}')
#
# File ~/miniconda3/envs/ada/lib/python3.9/site-packages/readlif/reader.py:380, in LifImage.get_frame(self, z, t, c, m)
#     377 if item_requested > total_items:
#     378     raise ValueError("The requested item is after the end of the image")
# --> 380 return self._get_item(item_requested)
#
# File ~/miniconda3/envs/ada/lib/python3.9/site-packages/readlif/reader.py:161, in LifImage._get_item(self, n)
#     159     data = b"\00" * image_len
#     160 else:
# --> 161     data = image.read(image_len)
#     163 # LIF files can be either 8-bit of 16-bit.
#     164 # Because of how the image is read in, all of the raw
#     165 # data is already in 'data', we just need to tell Pillow
#    (...)
#     169 # len(data) is the number of bytes (8-bit)
#     170 # However, it is safer to let the lif file tell us the resolution
#     171 if self.bit_depth[0] == 8:
#
# KeyboardInterrupt:
